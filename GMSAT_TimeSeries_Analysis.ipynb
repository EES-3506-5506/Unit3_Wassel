# %% [markdown]
# Time series plots of temperature anomalies. Author is Tyler Wassel for questions contact at twassel28@gmail.com

# %%
import pandas as pd                          
import matplotlib.pyplot as plt 
import numpy as np
import cmocean 

# %matplotlib inline                           
# %config InlineBackend.figure_format='retina' 
plt.rcParams['figure.figsize'] = 12,6

# %%
from matplotlib import cm
from matplotlib import colormaps as colormap
cool_warm_cmap = colormap["coolwarm"]
cool_warm_cmap

# %%
GISS_temp = pd.read_csv('./data/temp/gmt_GISTEMP.csv')
HadCRUT5_temp = pd.read_csv('./data/temp/gmt_HadCRUT5.csv')
JRA55_temp = pd.read_csv('./data/temp/gmt_JRA-55.csv')
Berkeley_temp= pd.read_csv('./data/temp/gmt_Berkeley_Earth.csv')
SST_temp= pd.read_csv('./data/temp/sst_ERSSTv5.csv')
NOAA_temp= pd.read_csv('./data/temp/gmt_NOAAGlobalTemp.csv')

# %%
fig, ax = plt.subplots(figsize = (10, 5))

ax.plot(GISS_temp['Year'],
        GISS_temp['GISTEMP (degC)'],
        linewidth=2,label='GISTEMP global mean surface air temp anomaly',
        color='black')


ax.legend() 


ax.axhline(0,color='k')


ax.set_title('Global Ave. Temperature anomaly (deg C) Relative to 1850 - 1900')


ax.set_ylabel('Temperataure anomaly (deg C)')
ax.set_xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# Global mean surface air temperature anomaly using GIS data with temperature on the y axis and the year on the x axis

# %%
fig, ax = plt.subplots(figsize = (10, 5))

ax.plot(HadCRUT5_temp['Year'],
        HadCRUT5_temp['HadCRUT5 (degC)'],
        linewidth=2,label='Had CRUT 5 global mean surface air temp anomaly',
        color='black')


ax.legend() 


ax.axhline(0,color='k')


ax.set_title('Global Ave. Temperature anomaly (deg C) Relative to 1850 - 1900')


ax.set_ylabel('Temperataure anomaly (deg C)')
ax.set_xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# Global mean surface air temperature anomaly using HadCRUT5 data with temperature on the y axis and the year on the x axis

# %%
fig, ax = plt.subplots(figsize = (10, 5))

ax.plot(JRA55_temp['Year'],
        JRA55_temp['JRA-55 (degC)'],
        linewidth=2,label='JRA-55 global mean surface air temp anomaly',
        color='black')


ax.legend() 


ax.axhline(0,color='k')


ax.set_title('Global Ave. Temperature anomaly (deg C) Relative to 1850 - 1900')

ax.set_ylabel('Temperataure anomaly (deg C)')
ax.set_xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# Global mean surface air temperature anomaly using JRA-55 data with temperature on the y axis and the year on the x axis

# %%
Berkeley_temp
# Out:
#      Year  Berkeley Earth (degC)  Berkeley Earth uncertainty
# 0    1850                  -0.22                       0.644
# 1    1851                  -0.10                       0.605
# 2    1852                  -0.08                       0.615
# 3    1853                  -0.08                       0.566
# 4    1854                  -0.07                       0.565
# ..    ...                    ...                         ...
# 169  2019                   1.26                       0.076
# 170  2020                   1.28                       0.075
# 171  2021                   1.13                       0.077
# 172  2022                   1.17                       0.081
# 173  2023                   1.28                       0.089
#
# [174 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize = (10, 5))

ax.plot(Berkeley_temp['Year'],
        Berkeley_temp['Berkeley Earth (degC)'],
        linewidth=2,label='Berkeley global mean surface air temp anomaly',
        color='black')


ax.legend() 


ax.axhline(0,color='k')


ax.set_title('Global Ave. Temperature anomaly (deg C) Relative to 1850 - 1900')

ax.set_ylabel('Temperataure anomaly (deg C)')
ax.set_xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# Global mean surface air temperature anomaly using Berkeley data with temperature on the y axis and the year on the x axis

# %%
fig, ax = plt.subplots(figsize = (10, 5))

ax.plot(SST_temp['Year'],
        SST_temp['ERSSTv5 (degC)'],
        linewidth=2,label='ERSSTv5 mean surface air temp anomaly',
        color='black')


ax.legend() 


ax.axhline(0,color='k')


ax.set_title('Global Ave. Temperature anomaly (deg C) Relative to 1850 - 1900')

ax.set_ylabel('Temperataure anomaly (deg C)')
ax.set_xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# Global mean surface air temperature anomaly using ERSSTv5 data with temperature on the y axis and the year on the x axis

# %%
fig, ax = plt.subplots(figsize = (10, 5))

ax.plot(NOAA_temp['Year'],
        NOAA_temp['NOAAGlobalTemp (degC)'],
        linewidth=2,label='NOAA global mean surface air temp anomaly',
        color='black')


ax.legend() 


ax.axhline(0,color='k')


ax.set_title('Global Ave. Temperature anomaly (deg C) Relative to 1850 - 1900')

ax.set_ylabel('Temperataure anomaly (deg C)')
ax.set_xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# Global mean surface air temperature anomaly using NOAA data with temperature on the y axis and the year on the x axis

# %%
fig, ax = plt.subplots(figsize = (10, 5))

### add the GISS temp dataset to the plot first:
ax.plot(GISS_temp['Year'],
        GISS_temp['GISTEMP (degC)'],
        linewidth=2,label='GISTEMP global mean surface air temp anomaly',
        color='black')

### add the hadcrut5 dataset on top and change our label and color!
ax.plot(HadCRUT5_temp['Year'],
        HadCRUT5_temp['HadCRUT5 (degC)'],
        linewidth=2,label='HadCRUT5 global mean surface air temp anomaly',
        color='red')

### add the JRA-55 dataset on top and change our label and color!
ax.plot(JRA55_temp['Year'],
        JRA55_temp['JRA-55 (degC)'],
        linewidth=2,label='JRA-55 global mean surface air temp anomaly',
        color='orange')

ax.plot(Berkeley_temp['Year'],
        Berkeley_temp['Berkeley Earth (degC)'],
        linewidth=2,label='Berkeley global mean surface air temp anomaly',
        color='blue')

ax.plot(SST_temp['Year'],
        SST_temp['ERSSTv5 (degC)'],
        linewidth=2,label='ERSSTv5 mean surface air temp anomaly',
        color='purple')

ax.plot(NOAA_temp['Year'],
        NOAA_temp['NOAAGlobalTemp (degC)'],
        linewidth=2,label='NOAA global mean surface air temp anomaly',
        color='green')



ax.legend() 


ax.axhline(0,color='gray')


ax.set_title('Global Ave. Temperature anomaly (deg C) Relative to 1850 - 1900')


ax.set_ylabel('Temperataure anomaly (deg C)')
ax.set_xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# Global mean surface air temperature anomaly using GIS,HadCrut5, JRA-55, Berkeley, ERSSTv5, and NOAA data with temperature on the y axis and the year on the x axis. All data sets are plotted on the same graph.

# %%
NOAA_temp_values = NOAA_temp['NOAAGlobalTemp (degC)']  ### Set the values to be used in our colormap
norm = plt.Normalize(min(NOAA_temp_values), 
                     max(NOAA_temp_values))

# Apply colormap --- two different colormaps as examples
cmap_coolwarm = colormap.get_cmap('coolwarm')
cmap_thermal = colormap.get_cmap(cmocean.cm.thermal)

bar_colors_coolwarm = cmap_coolwarm(norm(NOAA_temp_values))
bar_colors_thermal = cmap_thermal(norm(NOAA_temp_values))

# %%
fig, ax = plt.subplots(figsize = (10, 5))


    
ax.fill_between(NOAA_temp['Year'], 0, NOAA_temp['NOAAGlobalTemp (degC)'], where=(NOAA_temp['NOAAGlobalTemp (degC)'] >= index),
             color = color,)
ax.bar(NOAA_temp['Year'],
        NOAA_temp['NOAAGlobalTemp (degC)'],
        linewidth=2,label='NOAA global mean surface air temp anomaly',
        color=bar_colors_thermal)

ax.plot(NOAA_temp['Year'],
        NOAA_temp['NOAAGlobalTemp (degC)'],
        linewidth=0.8,
        color='white')

ax.legend() 


ax.axhline(0,color='k')

ax.set_ylabel('Temperature Anomaly (Deg C)')
ax.set_xlabel('Time (in years)')

ax.set_title('Global Ave. Temperature anomaly (deg C) Relative to 1850 - 1900')

ax.set_facecolor("k")
ax.axhline(0,color='white',linewidth=0.5)

# %% [markdown]
# Bar graph with color gradient to indicate magnitude of temperature anomaly in degrees Celsius. The year is on the x axis and the temperature is on the y axis.
